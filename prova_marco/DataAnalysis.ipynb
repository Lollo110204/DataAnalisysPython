# %%
import pandas as pd 
import numpy as np
import plotly.express as px 

df = pd.read_csv("PopolationGrowth.csv")

display(df)
# Out:
#                     Country Name Country Code                Indicator Name  \
# 0                          Aruba          ABW  Population growth (annual %)
# 1    Africa Eastern and Southern          AFE  Population growth (annual %)
# 2                    Afghanistan          AFG  Population growth (annual %)
# 3     Africa Western and Central          AFW  Population growth (annual %)
# 4                         Angola          AGO  Population growth (annual %)
# ..                           ...          ...                           ...
# 260                       Kosovo          XKX  Population growth (annual %)
# 261                   Yemen Rep.          YEM  Population growth (annual %)
# 262                 South Africa          ZAF  Population growth (annual %)
# 263                       Zambia          ZMB  Population growth (annual %)
# 264                     Zimbabwe          ZWE  Population growth (annual %)
#
# ...
