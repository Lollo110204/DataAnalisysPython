# %%
import pandas as pd 
import numpy as np
import plotly.express as px

df = pd.read_csv("Air_Quality.csv")

display(df)
# Out:
#        Unique ID  Indicator ID                    Name Measure Measure Info  \
# 0         336867           375  Nitrogen dioxide (NO2)    Mean          ppb
# 1         336741           375  Nitrogen dioxide (NO2)    Mean          ppb
# 2         550157           375  Nitrogen dioxide (NO2)    Mean          ppb
# 3         412802           375  Nitrogen dioxide (NO2)    Mean          ppb
# 4         412803           375  Nitrogen dioxide (NO2)    Mean          ppb
# ...          ...           ...                     ...     ...          ...
# 18857     165993           375  Nitrogen dioxide (NO2)    Mean          ppb
# 18858     338255           386              Ozone (O3)    Mean          ppb
# 18859     651029           386              Ozone (O3)    Mean          ppb
# 18860     667628           375  Nitrogen dioxide (NO2)    Mean          ppb
# 18861     167586           375  Nitrogen dioxide (NO2)    Mean          ppb
#
# ...

# %%
fig = px.pie(
    df,
    values="Data_Value",
    names="Name",
    title="Type of air pollutants in the air",
)

fig.show()

# %%
fig1 = px.density_heatmap(
    df,
    x='Name',
    y='Geo_Type_Name',
    z='Data_Value',
    width=1000,
    height=800,
    labels={'Name':'Nome','Geo_Type_Name':'Geography type name','Data_Value':'Value'}
)

fig1.show()

# %%
# Estrai anno

df['Start_Date'] = pd.to_datetime(df['Start_Date'], errors='coerce', dayfirst=True)
df['Year'] = df['Start_Date'].dt.year


# Calcola la media di Data_Value per anno e località
df_yearly = df.groupby(['Year', 'Geo_Place_Name'])['Data_Value'].mean().reset_index()

# Grafico andamento medio annuale NO2 per località
fig2 = px.line(
    df_yearly,
    x='Year',
    y='Data_Value',
    color='Geo_Place_Name',
    line_group='Geo_Place_Name',
    title='Andamento medio annuale di NO2 per località'
)
fig2.show()

# %%
def convert_excel_to_csv(file_excel, file_csv, sheet_name=0):
    df = pd.read_excel(file_excel, sheet_name=sheet_name)
    df.to_csv(file_csv, index=False)
    




df_prezzi = pd.read_csv("prezzo_beni_alimentari.csv")

df_prezzi_pulito = pd.melt(df_prezzi, id_vars=["ANNI"], 
                  var_name="Prodotto", 
                  value_name="Prezzo_al_kg")


# Converte Prezzo_al_kg in numerico (float), sostituendo errori con NaN
df_prezzi_pulito["Prezzo_al_kg"] = pd.to_numeric(df_prezzi_pulito["Prezzo_al_kg"], errors='coerce')
# Crea una colonna per il size del bubble con trasformazione logaritmica (valori piccoli + visibili)
df_prezzi_pulito["size_bubble"] = df_prezzi_pulito["Prezzo_al_kg"].apply(lambda x: np.log(x + 1) * 10)

# Rimuove i valori nulli
df_prezzi_pulito = df_prezzi_pulito.dropna(subset=["Prezzo_al_kg"])

fig = px.line(
    df_prezzi_pulito,
    x='ANNI',
    y='Prezzo_al_kg',
    color="Prodotto"
)

fig.show()

# %% [markdown]
# converto il dataframe e ribalto righe e colonne per una migliore analisi , per ribaltare il df uso il comando melt

# %%
df_prezzi = pd.read_csv("prezzo_beni_alimentari.csv")

df_prezzi_pulito = pd.melt(df_prezzi, id_vars=["ANNI"], 
                  var_name="Prodotto", 
                  value_name="Prezzo_al_kg")


# Converte Prezzo_al_kg in numerico (float), sostituendo errori con NaN
df_prezzi_pulito["Prezzo_al_kg"] = pd.to_numeric(df_prezzi_pulito["Prezzo_al_kg"], errors='coerce')
# Crea una colonna per il size del bubble con trasformazione logaritmica (valori piccoli + visibili)
df_prezzi_pulito["size_bubble"] = df_prezzi_pulito["Prezzo_al_kg"].apply(lambda x: np.log(x + 1) * 10)

# Rimuove i valori nulli
df_prezzi_pulito = df_prezzi_pulito.dropna(subset=["Prezzo_al_kg"])

df_prezzi_pulito
# Out:
#       ANNI      Prodotto  Prezzo_al_kg  size_bubble
# 0     1861     Pane_(Kg)       0.00021     0.002100
# 1     1862     Pane_(Kg)       0.00020     0.002000
# 2     1863     Pane_(Kg)       0.00019     0.001900
# 3     1864     Pane_(Kg)       0.00019     0.001900
# 4     1865     Pane_(Kg)       0.00017     0.001700
# ...    ...           ...           ...          ...
# 1235  2011  Uova_(pezzo)       0.22000     1.988509
# 1236  2012  Uova_(pezzo)       0.24000     2.151114
# 1237  2013  Uova_(pezzo)       0.25000     2.231436
# 1238  2014  Uova_(pezzo)       0.26000     2.311117
# 1239  2015  Uova_(pezzo)       0.25000     2.231436
#
# [1202 rows x 4 columns]

# %% [markdown]
# creo il grafico con il df ribnaltato

# %%
fig = px.pie(
    df_prezzi_pulito,
    names='Prodotto',
    values='Prezzo_al_kg',
    title='Distribuzione dei prezzi dei prodotti alimentari nel tempo', 
    
)

fig.show()

# %% [markdown]
# Creiamo una funzione che permetta di fare la conversione da xlxs a csv ( serve nel caso i dati siano su una tabella excell ma a noi servono in csv per poterli anlizxzare meglio)

# %%
def convert_to_csv(file_excell,file_csv):
    df = pd.read_excel(file_excell)
    return df.to_csv(file_csv, index=False)



convert_to_csv("WorldBank.xlsx","WorldBank.csv")

# %% [markdown]
# ora creiamo il df e rinominiamo i campi del nostro csv siccome avere spazi all'interno dei nomi delle colonne danno molti problemi in fase di analisi

# %%
df_world_bank = pd.read_csv("WorldBank.csv")

df_world_bank = df_world_bank.rename(columns={
    'Country Name' : 'Country_name',
    'Country Code' : 'Country_code',
    'Birth rate, crude (per 1,000 people)' : 'Birth_rate_crude',
    'Death rate, crude (per 1,000 people)' : 'Death_rate_crude',
    'Electric power consumption (kWh per capita)'  : 'Electric_power_consumption_kWh_per_capita',
    'GDP (USD)' : 'GDP_USD',
    'GDP per capita (USD)' : 'GDP_per_capita_USD',
    'Individuals using the Internet (% of population)' : 'Individuals_using_Internet_percent_population',
    'Infant mortality rate (per 1,000 live births)' : 'Infant_mortality_rate_per_1000_live_births',
    'Life expectancy at birth (years)' : 'Life_expectancy_at_birth_years',
    'Population density (people per sq. km of land area)' : 'Population_density_people_per_sq_km_land_area',
    'Unemployment (% of total labor force) (modeled ILO estimate)' : 'Unemployment_percent_total_labor_force_modeled_ILO_estimate'
})

display(df_world_bank)
display(df_world_bank.describe())
# Out:
#       Country_name Country_code              Region IncomeGroup  Year  \
# 0      Afghanistan          AFG          South Asia  Low income  2018
# 1      Afghanistan          AFG          South Asia  Low income  2017
# 2      Afghanistan          AFG          South Asia  Low income  2016
# 3      Afghanistan          AFG          South Asia  Low income  2015
# 4      Afghanistan          AFG          South Asia  Low income  2014
# ...            ...          ...                 ...         ...   ...
# 12444     Zimbabwe          ZWE  Sub-Saharan Africa  Low income  1964
# 12445     Zimbabwe          ZWE  Sub-Saharan Africa  Low income  1963
# 12446     Zimbabwe          ZWE  Sub-Saharan Africa  Low income  1962
# 12447     Zimbabwe          ZWE  Sub-Saharan Africa  Low income  1961
# 12448     Zimbabwe          ZWE  Sub-Saharan Africa  Low income  1960
#
#        Birth_rate_crude  Death_rate_crude  \
# 0                   NaN               NaN
# ...

# %%
fig = px.bar(
    df_world_bank,
    x="Country_name",
    y="Death_rate_crude",
    color="Country_name",
    labels={"Country_name": "Nome del paese", "Death_rate_crude": "Tasso di mortalità per anno (per 1000 abitanti)"},
    title="Tasso di mortalità per paese"
)

fig.show()

# %%
fig = px.choropleth(
    df_world_bank,
    locations="Country_name",
    locationmode="country names",  # <-- CORRETTO
    color="Death_rate_crude",
    projection="natural earth",
    labels={"Country_name": "Nome del paese", "Death_rate_crude": "Tasso di mortalità per anno (per 1000 abitanti)"},
    title="Tasso di mortalità per paese"
)

fig.show()

# %%
fig = px.choropleth(
    df_world_bank,
    locations="Country_name",
    locationmode="country names",  # <-- CORRETTO
    color="Birth_rate_crude",
    projection="natural earth",
    labels={"Country_name": "Nome del paese", "Death_rate_crude": "Tasso di mortalità per anno (per 1000 abitanti)"},
    title="Tasso di natalità per paese"
)

fig.show()
